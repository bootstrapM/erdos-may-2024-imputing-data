# %%
import pandas as pd

# %%
df = pd.read_csv("apple_2023_masked.csv")

# %%
len(df[df["1day"].isna()])
# Out:
# 7

# %%
df
# Out:
#                           Date        Open        High         Low  \
# 0    2023-01-03 00:00:00-05:00  129.215470  129.830399  123.155395
# 1    2023-01-04 00:00:00-05:00  125.853183  127.608724  124.057975
# 2    2023-01-05 00:00:00-05:00  126.091211  126.725981  123.740581
# 3    2023-01-06 00:00:00-05:00  124.980372  129.225391  123.869520
# 4    2023-01-09 00:00:00-05:00  129.403910  132.319889  128.828647
# ..                         ...         ...         ...         ...
# 245  2023-12-22 00:00:00-05:00  194.667221  194.896627  192.463035
# 246  2023-12-26 00:00:00-05:00  193.101342  193.380606  192.323393
# 247  2023-12-27 00:00:00-05:00  191.984293  192.991634  190.587962
# 248  2023-12-28 00:00:00-05:00  193.629953  194.148591  192.662500
# 249  2023-12-29 00:00:00-05:00  193.390581  193.889267  191.226284
#
#           Close     Volume  Dividends  Stock Splits        1day        2day  \
# 0    124.048042  112117500        0.0           0.0  124.048042  124.048042
# ...
