# %%
import tensorflow as tf

from tensorflow import keras

from tensorflow.keras import layers

from tensorflow.keras.layers.experimental import preprocessing

import numpy as np

import pandas as pd

import statistics as stat

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
# Out:
# C:\Users\serge\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       1 import tensorflow as tf
#       3 from tensorflow import keras
# ----> 5 from tensorflow.keras import layers
#       7 from tensorflow.keras.layers.experimental import preprocessing
#       9 import numpy as np
#
# File ~\anaconda3\lib\site-packages\keras\_tf_keras\keras\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:10, in <module>
#       7 import os
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras.api import *  # noqa: F403
#      11 from keras.api import __version__  # Import * ignores names start with "_".
#      13 # Add everything in /api/ to the module search path.
#
# File ~\anaconda3\lib\site-packages\keras\api\__init__.py:8, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File ~\anaconda3\lib\site-packages\keras\api\activations\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File ~\anaconda3\lib\site-packages\keras\src\__init__.py:1, in <module>
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\anaconda3\lib\site-packages\keras\src\activations\__init__.py:3, in <module>
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File ~\anaconda3\lib\site-packages\keras\src\activations\activations.py:1, in <module>
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\__init__.py:9, in <module>
#       3 if backend() == "torch":
#       4     # When using the torch backend,
#       5     # torch needs to be imported first, otherwise it will segfault
#       6     # upon import.
#       7     import torch
# ----> 9 from keras.src.backend.common.dtypes import result_type
#      10 from keras.src.backend.common.keras_tensor import KerasTensor
#      11 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\__init__.py:2, in <module>
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import KerasVariable
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\dtypes.py:5, in <module>
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\variables.py:11, in <module>
#       9 from keras.src.backend.common.stateless_scope import in_stateless_scope
#      10 from keras.src.utils.module_utils import tensorflow as tf
# ---> 11 from keras.src.utils.naming import auto_name
#      14 class KerasVariable:
#      15     """Represents a backend-agnostic variable in Keras.
#      16
#      17     A `Variable` acts as a container for state. It holds a tensor value and can
#    (...)
#      77     ```
#      78     """
#
# File ~\anaconda3\lib\site-packages\keras\src\utils\__init__.py:12, in <module>
#      10 from keras.src.utils.io_utils import enable_interactive_logging
#      11 from keras.src.utils.io_utils import is_interactive_logging_enabled
# ---> 12 from keras.src.utils.model_visualization import model_to_dot
#      13 from keras.src.utils.model_visualization import plot_model
#      14 from keras.src.utils.numerical_utils import normalize
#
# File ~\anaconda3\lib\site-packages\keras\src\utils\model_visualization.py:6, in <module>
#       3 import os
#       4 import sys
# ----> 6 from keras.src import tree
#       7 from keras.src.api_export import keras_export
#       8 from keras.src.utils import io_utils
#
# File ~\anaconda3\lib\site-packages\keras\src\tree\__init__.py:1, in <module>
# ----> 1 from keras.src.tree.tree_api import assert_same_structure
#       2 from keras.src.tree.tree_api import flatten
#       3 from keras.src.tree.tree_api import is_nested
#
# File ~\anaconda3\lib\site-packages\keras\src\tree\tree_api.py:10, in <module>
#       8     from keras.src.tree import dmtree_impl as tree_impl
#       9 else:
# ---> 10     raise ImportError(
#      11         "To use Keras, you need to have `optree` installed. "
#      12         "Install it via `pip install optree`"
#      13     )
#      16 def register_tree_node_class(cls):
#      17     return tree_impl.register_tree_node_class(cls)
#
# ImportError: To use Keras, you need to have `optree` installed. Install it via `pip install optree`

# %%
data = pd.read_csv(r"C:\Users\serge\Documents\SergeiNotebooks\input_test_4AhEauI.csv")

# %%
data.head()

# %%
data

# %%
import yfinance as yf

# %%
pip install yfinance

# %%
appl = yf.Ticker('AAPL')
appl.info

# %%
end_date = pd.Timestamp.now()
start_date = end_date - pd.DateOffset(years=1)

apple_data = appl.history(start = start_date, end = end_date)

apple_data.head()

# %%
random_state = 27
np.random.seed(random_state)


missing_dates = np.random.choice(apple_data.index, size=5, replace=False)
apple_missing = apple_data.copy()
apple_missing.loc[missing_dates, 'Close'] = np.nan

# %%
apple_missing.head()

# %%
len(apple_missing)

# %%
missing_index = apple_missing[apple_missing['Close'].isna()].index
print(missing_index)

# %%
install python3

# %%
pip install optree

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\serge\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall keras
pip uninstall tensorflow
pip cache purge
pip install tensorflow --ignore-installed --user
# Out:
#   Input In [3]
#     pip uninstall keras
#         ^
# SyntaxError: invalid syntax

# %%
print(keras.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py:147, in KerasLazyLoader._initialize(self)
#     146 try:
# --> 147   import keras  # pylint: disable=g-import-not-at-top
#     149   if keras.__version__.startswith("3."):
#     150     # This is the Keras 3.x case.
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:10, in <module>
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras.api import *  # noqa: F403
#      11 from keras.api import __version__  # Import * ignores names start with "_".
#
# File ~\anaconda3\lib\site-packages\keras\api\__init__.py:8, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#
# File ~\anaconda3\lib\site-packages\keras\api\activations\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#
# File ~\anaconda3\lib\site-packages\keras\src\__init__.py:1, in <module>
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#
# File ~\anaconda3\lib\site-packages\keras\src\activations\__init__.py:3, in <module>
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#
# File ~\anaconda3\lib\site-packages\keras\src\activations\activations.py:1, in <module>
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\__init__.py:9, in <module>
#       7     import torch
# ----> 9 from keras.src.backend.common.dtypes import result_type
#      10 from keras.src.backend.common.keras_tensor import KerasTensor
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\__init__.py:2, in <module>
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\dtypes.py:5, in <module>
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\variables.py:11, in <module>
#      10 from keras.src.utils.module_utils import tensorflow as tf
# ---> 11 from keras.src.utils.naming import auto_name
#      14 class KerasVariable:
#
# File ~\anaconda3\lib\site-packages\keras\src\utils\__init__.py:12, in <module>
#      11 from keras.src.utils.io_utils import is_interactive_logging_enabled
# ---> 12 from keras.src.utils.model_visualization import model_to_dot
#      13 from keras.src.utils.model_visualization import plot_model
#
# File ~\anaconda3\lib\site-packages\keras\src\utils\model_visualization.py:6, in <module>
#       4 import sys
# ----> 6 from keras.src import tree
#       7 from keras.src.api_export import keras_export
#
# File ~\anaconda3\lib\site-packages\keras\src\tree\__init__.py:1, in <module>
# ----> 1 from keras.src.tree.tree_api import assert_same_structure
#       2 from keras.src.tree.tree_api import flatten
#
# File ~\anaconda3\lib\site-packages\keras\src\tree\tree_api.py:10, in <module>
#       9 else:
# ---> 10     raise ImportError(
#      11         "To use Keras, you need to have `optree` installed. "
#      12         "Install it via `pip install optree`"
#      13     )
#      16 def register_tree_node_class(cls):
#
# ImportError: To use Keras, you need to have `optree` installed. Install it via `pip install optree`
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print(keras.__version__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py:181, in KerasLazyLoader.__getattr__(self, item)
#     179   return super(types.ModuleType, self).__getattribute__(item)
#     180 if not self._tfll_initialized:
# --> 181   self._initialize()
#     182 if self._tfll_keras_version == "keras_3":
#     183   if (
#     184       self._tfll_mode == "v1"
#     185       and not self._tfll_submodule
#     186       and item.startswith("compat.v1.")
#     187   ):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py:161, in KerasLazyLoader._initialize(self)
#     159         package_name = "keras.api._v2.keras"
#     160   except ImportError:
# --> 161     raise ImportError(  # pylint: disable=raise-missing-from
#     162         "Keras cannot be imported. Check that it is installed."
#     163     )
#     165 self._tfll_keras_version = keras_version
#     166 if keras_version is not None:
#
# ImportError: Keras cannot be imported. Check that it is installed.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\serge\anaconda3\lib\site-packages (3.3.3)
# Requirement already satisfied: optree in c:\users\serge\anaconda3\lib\site-packages (from keras) (0.11.0)
# Requirement already satisfied: numpy in c:\users\serge\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: absl-py in c:\users\serge\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: namex in c:\users\serge\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: rich in c:\users\serge\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: h5py in c:\users\serge\anaconda3\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\serge\anaconda3\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\serge\anaconda3\lib\site-packages (from optree->keras) (4.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\serge\anaconda3\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\serge\anaconda3\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\serge\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
