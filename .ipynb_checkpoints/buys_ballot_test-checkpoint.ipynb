# %% [markdown]
# ### This jupyter notebook is to test the yahoo finance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
from pandas_datareader import data as pdr

# %%
aapl = yf.Ticker("AAPL")

# %% [markdown]
# ## aapl.history: get historical market data

# %% [markdown]
# Valid options for "period": 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo, 1y, 2y, 5y, 10y and ytd.

# %%
df = aapl.history(period="10y")

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-05-19 00:00:00-04:00   18.886408   19.185887   18.869981   19.099329
# 2014-05-20 00:00:00-04:00   19.096804   19.156510   18.977392   19.103123
# 2014-05-21 00:00:00-04:00   19.075317   19.165981   19.019403   19.153662
# 2014-05-22 00:00:00-04:00   19.162827   19.265497   19.083852   19.183992
# 2014-05-23 00:00:00-04:00   19.183361   19.419658   19.158720   19.400703
# ...                               ...         ...         ...         ...
# 2024-05-10 00:00:00-04:00  184.899994  185.089996  182.130005  183.050003
# 2024-05-13 00:00:00-04:00  185.440002  187.100006  184.619995  186.279999
# 2024-05-14 00:00:00-04:00  187.509995  188.300003  186.289993  187.429993
# 2024-05-15 00:00:00-04:00  187.910004  190.649994  187.369995  189.720001
# 2024-05-16 00:00:00-04:00  190.516006  191.095001  189.660095  189.839996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = df.reset_index().copy()

# %%
#df['Date']= pd.to_datetime(df['Date'])

# %%
df['Date']= df['Date'].dt.strftime('%m/%d/%Y')

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date        Open        High         Low       Close     Volume  \
# 0    2014-05-19   18.886408   19.185887   18.869981   19.099329  317755200
# 1    2014-05-20   19.096804   19.156510   18.977392   19.103123  234836000
# 2    2014-05-21   19.075317   19.165981   19.019403   19.153662  196859600
# 3    2014-05-22   19.162827   19.265497   19.083852   19.183992  200760000
# 4    2014-05-23   19.183361   19.419658   19.158720   19.400703  232209600
# ...         ...         ...         ...         ...         ...        ...
# 2512 2024-05-10  184.899994  185.089996  182.130005  183.050003   50759500
# 2513 2024-05-13  185.440002  187.100006  184.619995  186.279999   72044800
# 2514 2024-05-14  187.509995  188.300003  186.289993  187.429993   52393600
# 2515 2024-05-15  187.910004  190.649994  187.369995  189.720001   70400000
# 2516 2024-05-16  190.516006  191.095001  189.660095  189.839996   52779567
#
#       Dividends  Stock Splits
# 0          0.00           0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2517 non-null   datetime64[ns]
#  1   Open          2517 non-null   float64
#  2   High          2517 non-null   float64
#  3   Low           2517 non-null   float64
#  4   Close         2517 non-null   float64
#  5   Volume        2517 non-null   int64
#  6   Dividends     2517 non-null   float64
#  7   Stock Splits  2517 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 157.4 KB

# %%
datetime(2023,1,1)
# Out:
# datetime.datetime(2023, 1, 1, 0, 0)

# %%
df_2023 = df[(df['Date'] > datetime(2023,1,1)) & (df['Date'] <= datetime(2023,12,31))]

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 2172 to 2421
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          250 non-null    datetime64[ns]
#  1   Open          250 non-null    float64
#  2   High          250 non-null    float64
#  3   Low           250 non-null    float64
#  4   Close         250 non-null    float64
#  5   Volume        250 non-null    int64
#  6   Dividends     250 non-null    float64
#  7   Stock Splits  250 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.6 KB

# %%
df_2023[['Date','Close']]
# Out:
#            Date       Close
# 2172 2023-01-03  124.048042
# 2173 2023-01-04  125.327507
# 2174 2023-01-05  123.998451
# 2175 2023-01-06  128.560867
# 2176 2023-01-09  129.086533
# ...         ...         ...
# 2417 2023-12-22  193.091385
# 2418 2023-12-26  192.542816
# 2419 2023-12-27  192.642548
# 2420 2023-12-28  193.071426
# 2421 2023-12-29  192.024185
#
# [250 rows x 2 columns]

# %%
df_2022 = df[(df['Date'] > datetime(2022,1,1)) & (df['Date'] <= datetime(2022,12,31))]

# %%
df_2022[['Date','Close']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries, 1921 to 2171
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    251 non-null    datetime64[ns]
#  1   Close   251 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.9 KB

# %%
df_2022[['Date','Close']]
# Out:
#            Date       Close
# 1921 2022-01-03  179.481125
# 1922 2022-01-04  177.203201
# 1923 2022-01-05  172.489655
# 1924 2022-01-06  169.610199
# 1925 2022-01-07  169.777832
# ...         ...         ...
# 2167 2022-12-23  130.782562
# 2168 2022-12-27  128.967514
# 2169 2022-12-28  125.010117
# 2170 2022-12-29  128.550964
# 2171 2022-12-30  128.868317
#
# [251 rows x 2 columns]

# %% [markdown]
# ## Plotting

# %%
df_2021 = df[(df['Date'] > datetime(2021,1,1)) & (df['Date'] <= datetime(2021,12,31))]

# %%
df_2020 = df[(df['Date'] > datetime(2020,1,1)) & (df['Date'] <= datetime(2020,12,31))]

# %%
df_2019 = df[(df['Date'] > datetime(2019,1,1)) & (df['Date'] <= datetime(2019,12,31))]

# %%
df_2018 = df[(df['Date'] > datetime(2018,1,1)) & (df['Date'] <= datetime(2018,12,31))]

# %%
df_2017 = df[(df['Date'] > datetime(2017,1,1)) & (df['Date'] <= datetime(2017,12,31))]

# %%
plt.figure(figsize=(16,5))

plt.plot(range(len(df_2023)),df_2023.Close.values, 'r-',label='2023')
plt.plot(range(len(df_2022)),df_2022.Close.values, 'b-',label='2022')
plt.plot(range(len(df_2021)),df_2021.Close.values, 'g-',label='2021')
plt.plot(range(len(df_2020)),df_2020.Close.values, 'c-',label='2020')
plt.plot(range(len(df_2019)),df_2019.Close.values, 'm-',label='2019')
plt.plot(range(len(df_2018)),df_2018.Close.values, 'k-',label='2018')
plt.plot(range(len(df_2017)),df_2017.Close.values, 'r--',label='2017')


#plt.plot(df_2023.Date.values,df_2023.Close.values, 'r-',label='2023')
#plt.plot(df_2022.Date.values,df_2022.Close.values, 'b-',label='2022')

plt.legend(fontsize=12)

plt.xlabel('Trading dates', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)

plt.show()

# %%
plt.figure(figsize=(16,5))

plt.plot(range(len(df_2019)),df_2019.Close.values, 'm-',label='2019')
plt.plot(range(len(df_2018)),df_2018.Close.values, 'k-',label='2018')
plt.plot(range(len(df_2017)),df_2017.Close.values, 'r--',label='2017')


#plt.plot(df_2023.Date.values,df_2023.Close.values, 'r-',label='2023')
#plt.plot(df_2022.Date.values,df_2022.Close.values, 'b-',label='2022')

plt.legend(fontsize=12)

plt.xlabel('Trading dates', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)

plt.show()

# %% [markdown]
# ## Number of trading days varies between 250 and 253, with some exceptions
#
# The number of trading days in a year varies between 250 and 253. In 2023, the number of trading days is 252. We need to check the number of trading days for each year before analyzing the data. $$

# %% [markdown]
# ## Removing data randomly

# %%
df_2023_remove = df_2023
df_2023_remove=df_2023_remove.set_index('Date')

#df_2023_remove.loc[df_2023_remove.iloc[i_remove],'Close']
#print(np.nan)
#= np.nan
#df.loc[df['y'] == 'N/A','y'] = np.nan
#df
#df_2023_remove.info()
#['Open','High','Low','Close'].fillna()
#df_2023_remove = df

# %%
df_2023_remove
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2023-01-03  129.215470  129.830399  123.155395  124.048042  112117500
# 2023-01-04  125.853175  127.608717  124.057967  125.327507   89113600
# 2023-01-05  126.091211  126.725981  123.740581  123.998451   80962700
# 2023-01-06  124.980372  129.225391  123.869520  128.560867   87754700
# 2023-01-09  129.403925  132.319905  128.828663  129.086533   70790800
# ...                ...         ...         ...         ...        ...
# 2023-12-22  194.667221  194.896627  192.463035  193.091385   37122800
# 2023-12-26  193.101342  193.380606  192.323393  192.542816   28919300
# 2023-12-27  191.984293  192.991634  190.587962  192.642548   48087700
# 2023-12-28  193.629953  194.148591  192.662500  193.071426   34049900
# 2023-12-29  193.390581  193.889267  191.226284  192.024185   42628800
#
#             Dividends  Stock Splits
# Date
# 2023-01-03        0.0           0.0
# 2023-01-04        0.0           0.0
# ...

# %%
random_state = 432
np.random.seed(random_state)


missing_dates = np.random.choice(df_2023_remove.index, size=5, replace=False)

# %%
df_2023_remove.loc[missing_dates,'Close'] = np.nan

# %%
df_2023_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2023-01-03 to 2023-12-29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          250 non-null    float64
#  1   High          250 non-null    float64
#  2   Low           250 non-null    float64
#  3   Close         245 non-null    float64
#  4   Volume        250 non-null    int64
#  5   Dividends     250 non-null    float64
#  6   Stock Splits  250 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 23.7 KB

# %%
print(missing_dates)
# Out:
# ['2023-07-07T00:00:00.000000000' '2023-07-31T00:00:00.000000000'
#  '2023-02-27T00:00:00.000000000' '2023-08-03T00:00:00.000000000'
#  '2023-11-08T00:00:00.000000000']

# %% [markdown]
# ## Linear Interpolating

# %%
#df_2023_remove = df_2023_remove.reset_index()

# %%
df_2023_remove
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2023-01-03  129.215470  129.830399  123.155395  124.048042  112117500
# 2023-01-04  125.853175  127.608717  124.057967  125.327507   89113600
# 2023-01-05  126.091211  126.725981  123.740581  123.998451   80962700
# 2023-01-06  124.980372  129.225391  123.869520  128.560867   87754700
# 2023-01-09  129.403925  132.319905  128.828663  129.086533   70790800
# ...                ...         ...         ...         ...        ...
# 2023-12-22  194.667221  194.896627  192.463035  193.091385   37122800
# 2023-12-26  193.101342  193.380606  192.323393  192.542816   28919300
# 2023-12-27  191.984293  192.991634  190.587962  192.642548   48087700
# 2023-12-28  193.629953  194.148591  192.662500  193.071426   34049900
# 2023-12-29  193.390581  193.889267  191.226284  192.024185   42628800
#
#             Dividends  Stock Splits
# Date
# 2023-01-03        0.0           0.0
# 2023-01-04        0.0           0.0
# ...

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
test = (missing_dates[0] + np.timedelta64(1,'D'))

# %%
print(type(test))
#df_2023_remove.loc[test]
# Out:
# <class 'numpy.datetime64'>

# %%
df_2023_remove.loc[test]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1688774400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\data_imputation\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
#print(df_2023_remove.loc[missing_dates[0] + np.timedelta64(1,'D')].Close)
df_2023_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2023-01-03 to 2023-12-29
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          250 non-null    float64
#  1   High          250 non-null    float64
#  2   Low           250 non-null    float64
#  3   Close         245 non-null    float64
#  4   Volume        250 non-null    int64
#  5   Dividends     250 non-null    float64
#  6   Stock Splits  250 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 23.7 KB

# %%
#np.where(df_2023_remove.loc[missing_dates])

# %%
slope = np.zeros(5)
i=0
for m_date in missing_dates:
    print(df_2023_remove.loc[m_date+ np.timedelta64(1,'D')].Close)
    print(m_date)
    #y2 = df_2023_remove.loc[m_date + np.timedelta64(1,'D')].Close
    #y1 = df_2023_remove.loc[m_date - np.timedelta64(1,'D')].Close
    #slope[i] = (y2-y1)/2
    #print(df_2023_remove.loc[m_date + np.timedelta64(1,'D')])
    #slope[i] = (df_2023_remove.loc[m_date + np.timedelta64(1,'D')].Close.values() - df_2023_remove.loc[m_date - np.timedelta64(1,'D')].Close.values)/2
    i += 1
slope
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1688774400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\data_imputation\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...
